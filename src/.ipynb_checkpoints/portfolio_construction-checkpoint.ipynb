# %%
import measure as ms
import portfolio as pf
import os 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
path = os.path.normpath(os.getcwd() + os.sep + os.pardir)
path+= "/data/stock_prices.csv"

df = pd.read_csv(path, sep = ",", decimal = ".", encoding='latin-1')
df["Date"] = pd.to_datetime(df["Date"], format = "%Y/%m/%d")
df.set_index("Date",inplace = True)

# %%
df_returns, df_monthly_returns = ms.get_return(df)

# %%
df_returns
# Out:
#                 AAPL         F      INTC       PFE         T
# Date
# 2006-12-13       NaN       NaN       NaN       NaN       NaN
# 2006-12-14 -0.005615  0.033430  0.003381  0.006696  0.003094
# 2006-12-15 -0.009373 -0.004219  0.009148  0.003130  0.000000
# 2006-12-18 -0.025650 -0.007062 -0.005725  0.007410 -0.005328
# 2006-12-19  0.009828  0.021337 -0.008638  0.014324 -0.013533
# ...              ...       ...       ...       ...       ...
# 2021-12-07  0.035446  0.038502  0.030986  0.004662 -0.008591
# 2021-12-08  0.022783 -0.007515 -0.015598 -0.006187  0.003899
# 2021-12-09 -0.002970 -0.012115 -0.024541  0.013230 -0.009927
# 2021-12-10  0.028013  0.096065  0.002179  0.013441 -0.004359
# 2021-12-13 -0.020674 -0.047552 -0.011662  0.045851 -0.017513
#
# [3776 rows x 5 columns]

# %%
df_monthly_returns
# Out:
#                 AAPL         F      INTC       PFE         T
# Date
# 2006-12-31       NaN       NaN       NaN       NaN       NaN
# 2007-01-31  0.010490  0.082557  0.035062  0.013127  0.063707
# 2007-02-28 -0.013064 -0.027060 -0.047411 -0.038386 -0.022057
# 2007-03-31  0.098097 -0.002528 -0.036757  0.012019  0.071467
# 2007-04-30  0.074158  0.019011  0.123890  0.047506 -0.009039
# ...              ...       ...       ...       ...       ...
# 2021-08-31  0.042489 -0.065950  0.012869  0.076150 -0.022460
# 2021-09-30 -0.068037  0.086723 -0.014428 -0.066421 -0.014953
# 2021-10-31  0.058657  0.206215 -0.080330  0.016973 -0.046638
# 2021-11-30  0.105082  0.129194  0.011064  0.239178 -0.096200
# 2021-12-31  0.063158  0.064617  0.016260  0.027359 -0.017083
#
# [181 rows x 5 columns]

# %%
table_return = ms.get_tabel(df_returns)
table_return
# Out:
#                  AAPL      F   INTC    PFE      T
# annualize_rets   1.33   0.47   0.42   0.46   0.12
# annualize_vol    7.01   9.46   6.83   5.03   4.94
# sharpe_ratio    19.02   4.99   6.16   9.11   2.41
# drawdown       -60.87 -86.93 -55.19 -53.02 -45.55

# %%
table_return_monthly = ms.get_tabel(df_monthly_returns)
table_return_monthly
# Out:
#                   AAPL      F   INTC    PFE      T
# annualize_rets   32.23   9.69   9.31   9.85   2.47
# annualize_vol    31.03  51.20  24.59  20.58  17.85
# sharpe_ratio    103.89  18.92  37.88  47.87  13.83
# drawdown        -56.91 -80.15 -50.64 -50.05 -39.68

# %%
correlation = df_returns.corr()
correlation
# Out:
#           AAPL         F      INTC       PFE         T
# AAPL  1.000000  0.364114  0.510009  0.358984  0.398006
# F     0.364114  1.000000  0.397619  0.309876  0.405527
# INTC  0.510009  0.397619  1.000000  0.435983  0.472356
# PFE   0.358984  0.309876  0.435983  1.000000  0.485040
# T     0.398006  0.405527  0.472356  0.485040  1.000000

# %% [markdown]
# ## Creation of a portfolio

# %% [markdown]
# ### Equally risk contribution portfolio

# %%
w = pf.get_weights(df_returns)
ret = pf.portfolio_return(w,df_returns.T)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 9.819267028719974e-06
#             Iterations: 10
#             Function evaluations: 79
#             Gradient evaluations: 10

# %%
plt.figure(figsize = (8, 8))
x = w
plt.pie(x, labels = df.columns,
           colors = ['olivedrab', 'royalblue', 'maroon',"deeppink","cadetblue"],
           autopct = lambda x: str(round(x, 2)) + '%',
           pctdistance = 0.7, labeldistance = 1.2,
           shadow = True)
plt.tight_layout()
plt.savefig('output/weights.png')
plt.show()

# %%
plt.style.use('seaborn')
fig = plt.figure(figsize=(12, 8), dpi=120)
plt.plot((1+ret).cumprod(), color = 'cadetblue')
plt.xlabel("Dates")
plt.ylabel('Performance')

plt.title("Performance of the portfolio")

plt.grid(True)

plt.tight_layout()
plt.show()
fig.savefig('output/performance')
