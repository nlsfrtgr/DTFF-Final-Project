# %%
import measure as ms
import portfolio as pf
import os 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# %%
path = os.path.normpath(os.getcwd() + os.sep + os.pardir)
path+= "\data\stock_prices.csv"

df = pd.read_csv(path, sep = ",", decimal = ".", encoding='latin-1')
df["Date"] = pd.to_datetime(df["Date"], format = "%Y/%m/%d")
df.set_index("Date",inplace = True)
df
# Out:
#                   AAPL          F       INTC        PFE          T
# Date
# 2006-12-13    2.726727   4.640410  13.342145  13.112051  15.446491
# 2006-12-14    2.711417   4.795539  13.387261  13.199844  15.494290
# 2006-12-15    2.686003   4.775305  13.509727  13.241161  15.494290
# 2006-12-18    2.617108   4.741580  13.432382  13.339279  15.411736
# 2006-12-19    2.642828   4.842752  13.316359  13.530354  15.203176
# ...                ...        ...        ...        ...        ...
# 2021-12-07  171.179993  19.959999  52.570000  51.720001  23.080000
# 2021-12-08  175.080002  19.809999  51.750000  51.400002  23.170000
# 2021-12-09  174.559998  19.570000  50.480000  52.080002  22.940001
# 2021-12-10  179.449997  21.450001  50.590000  52.779999  22.840000
# 2021-12-13  175.740005  20.430000  50.000000  55.200001  22.440001
#
# [3776 rows x 5 columns]

# %%
createFolder('./output/')

path = os.path.normpath(os.getcwd() + os.sep + os.pardir)
path+= "/output/"

# %%
plt.style.use('seaborn')
fig = plt.figure(figsize=(12, 8), dpi=120)


plt.plot(df["AAPL"], color = 'olivedrab', label = "AAPL")
plt.plot(df["INTC"], color = 'navy', label = "INTC")
plt.plot(df["F"], color = 'maroon', label = "F")
plt.plot(df["PFE"], color = 'deeppink', label = "PFE")
plt.plot(df["T"], color = 'cadetblue', label = "T")
plt.xlabel("Dates")
plt.ylabel('Prices')

plt.title("Stocks prices",  weight='bold')

plt.legend()

plt.grid(True)

plt.tight_layout()
plt.show()
fig.savefig('output/price')
